# %%
# %pip install -r ./requirements.txt
# Out:
# Requirement already satisfied: ipykernel==7.1.0 in /home/leonardooliveira/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from -r ./requirements.txt (line 1)) (7.1.0)
# Collecting pyspark==3.5.7 (from -r ./requirements.txt (line 2))
#   Using cached pyspark-3.5.7-py2.py3-none-any.whl
# Collecting boto3==1.41.5 (from -r ./requirements.txt (line 3))
#   Obtaining dependency information for boto3==1.41.5 from https://files.pythonhosted.org/packages/3c/56/f47a80254ed4991cce9a2f6d8ae8aafbc8df1c3270e966b2927289e5a12f/boto3-1.41.5-py3-none-any.whl.metadata
#   Using cached boto3-1.41.5-py3-none-any.whl.metadata (6.8 kB)
# Collecting pandas==2.2.3 (from -r ./requirements.txt (line 4))
#   Obtaining dependency information for pandas==2.2.3 from https://files.pythonhosted.org/packages/cd/5f/4dba1d39bb9c38d574a9a22548c540177f78ea47b32f99c0ff2ec499fac5/pandas-2.2.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Using cached pandas-2.2.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (89 kB)
# Collecting google-auth-oauthlib==1.2.3 (from -r ./requirements.txt (line 5))
#   Obtaining dependency information for google-auth-oauthlib==1.2.3 from https://files.pythonhosted.org/packages/38/07/a54c100da461ffc5968457823fcc665a48fb4b875c68bcfecbfe24a10dbe/google_auth_oauthlib-1.2.3-py3-none-any.whl.metadata
#   Using cached google_auth_oauthlib-1.2.3-py3-none-any.whl.metadata (3.1 kB)
# Collecting google-api-python-client==2.187.0 (from -r ./requirements.txt (line 6))
#   Obtaining dependency information for google-api-python-client==2.187.0 from https://files.pythonhosted.org/packages/96/58/c1e716be1b055b504d80db2c8413f6c6a890a6ae218a65f178b63bc30356/google_api_python_client-2.187.0-py3-none-any.whl.metadata
#   Using cached google_api_python_client-2.187.0-py3-none-any.whl.metadata (7.0 kB)
# Collecting pysftpserver==1.4.0 (from -r ./requirements.txt (line 7))
#   Using cached pysftpserver-1.4.0-py3-none-any.whl
# Collecting paramiko==4.0.0 (from -r ./requirements.txt (line 8))
#   Obtaining dependency information for paramiko==4.0.0 from https://files.pythonhosted.org/packages/a9/90/a744336f5af32c433bd09af7854599682a383b37cfd78f7de263de6ad6cb/paramiko-4.0.0-py3-none-any.whl.metadata
#   Using cached paramiko-4.0.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: comm>=0.1.1 in /home/leonardooliveira/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from ipykernel==7.1.0->-r ./requirements.txt (line 1)) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /home/leonardooliveira/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from ipykernel==7.1.0->-r ./requirements.txt (line 1)) (1.8.17)
# Requirement already satisfied: ipython>=7.23.1 in /home/leonardooliveira/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from ipykernel==7.1.0->-r ./requirements.txt (line 1)) (9.8.0)
# Requirement already satisfied: jupyter-client>=8.0.0 in /home/leonardooliveira/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from ipykernel==7.1.0->-r ./requirements.txt (line 1)) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/leonardooliveira/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from ipykernel==7.1.0->-r ./requirements.txt (line 1)) (5.9.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/leonardooliveira/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from ipykernel==7.1.0->-r ./requirements.txt (line 1)) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in /home/leonardooliveira/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from ipykernel==7.1.0->-r ./requirements.txt (line 1)) (1.6.0)
# Requirement already satisfied: packaging>=22 in /home/leonardooliveira/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from ipykernel==7.1.0->-r ./requirements.txt (line 1)) (25.0)
# Requirement already satisfied: psutil>=5.7 in /home/leonardooliveira/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from ipykernel==7.1.0->-r ./requirements.txt (line 1)) (7.1.3)
# Requirement already satisfied: pyzmq>=25 in /home/leonardooliveira/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from ipykernel==7.1.0->-r ./requirements.txt (line 1)) (27.1.0)
# Requirement already satisfied: tornado>=6.2 in /home/leonardooliveira/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from ipykernel==7.1.0->-r ./requirements.txt (line 1)) (6.5.2)
# Requirement already satisfied: traitlets>=5.4.0 in /home/leonardooliveira/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from ipykernel==7.1.0->-r ./requirements.txt (line 1)) (5.14.3)
# Collecting py4j==0.10.9.7 (from pyspark==3.5.7->-r ./requirements.txt (line 2))
#   Obtaining dependency information for py4j==0.10.9.7 from https://files.pythonhosted.org/packages/10/30/a58b32568f1623aaad7db22aa9eafc4c6c194b429ff35bdc55ca2726da47/py4j-0.10.9.7-py2.py3-none-any.whl.metadata
#   Using cached py4j-0.10.9.7-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting botocore<1.42.0,>=1.41.5 (from boto3==1.41.5->-r ./requirements.txt (line 3))
#   Obtaining dependency information for botocore<1.42.0,>=1.41.5 from https://files.pythonhosted.org/packages/ab/d4/587a71c599997b0f7aa842ea71604348f5a7d239cfff338292904f236983/botocore-1.41.6-py3-none-any.whl.metadata
#   Using cached botocore-1.41.6-py3-none-any.whl.metadata (5.9 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3==1.41.5->-r ./requirements.txt (line 3))
#   Obtaining dependency information for jmespath<2.0.0,>=0.7.1 from https://files.pythonhosted.org/packages/31/b4/b9b800c45527aadd64d5b442f9b932b00648617eb5d63d2c7a6587b7cafc/jmespath-1.0.1-py3-none-any.whl.metadata
#   Using cached jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.16.0,>=0.15.0 (from boto3==1.41.5->-r ./requirements.txt (line 3))
#   Obtaining dependency information for s3transfer<0.16.0,>=0.15.0 from https://files.pythonhosted.org/packages/5f/e1/5ef25f52973aa12a19cf4e1375d00932d7fb354ffd310487ba7d44225c1a/s3transfer-0.15.0-py3-none-any.whl.metadata
#   Using cached s3transfer-0.15.0-py3-none-any.whl.metadata (1.7 kB)
# Collecting numpy>=1.23.2 (from pandas==2.2.3->-r ./requirements.txt (line 4))
#   Obtaining dependency information for numpy>=1.23.2 from https://files.pythonhosted.org/packages/65/fb/2b23769462b34398d9326081fad5655198fcf18966fcb1f1e49db44fbf31/numpy-2.3.5-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata
#   Using cached numpy-2.3.5-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/leonardooliveira/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from pandas==2.2.3->-r ./requirements.txt (line 4)) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas==2.2.3->-r ./requirements.txt (line 4))
#   Obtaining dependency information for pytz>=2020.1 from https://files.pythonhosted.org/packages/81/c4/34e93fe5f5429d7570ec1fa436f1986fb1f00c3e0f43a589fe2bbcd22c3f/pytz-2025.2-py2.py3-none-any.whl.metadata
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas==2.2.3->-r ./requirements.txt (line 4))
#   Obtaining dependency information for tzdata>=2022.7 from https://files.pythonhosted.org/packages/5c/23/c7abc0ca0a1526a0774eca151daeb8de62ec457e77262b66b359c3c7679e/tzdata-2025.2-py2.py3-none-any.whl.metadata
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting google-auth<2.42.0,>=2.15.0 (from google-auth-oauthlib==1.2.3->-r ./requirements.txt (line 5))
#   Obtaining dependency information for google-auth<2.42.0,>=2.15.0 from https://files.pythonhosted.org/packages/be/a4/7319a2a8add4cc352be9e3efeff5e2aacee917c85ca2fa1647e29089983c/google_auth-2.41.1-py2.py3-none-any.whl.metadata
#   Using cached google_auth-2.41.1-py2.py3-none-any.whl.metadata (6.6 kB)
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib==1.2.3->-r ./requirements.txt (line 5))
#   Obtaining dependency information for requests-oauthlib>=0.7.0 from https://files.pythonhosted.org/packages/3b/5d/63d4ae3b9daea098d5d6f5da83984853c1bbacd5dc826764b249fe119d24/requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata
#   Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Collecting httplib2<1.0.0,>=0.19.0 (from google-api-python-client==2.187.0->-r ./requirements.txt (line 6))
#   Obtaining dependency information for httplib2<1.0.0,>=0.19.0 from https://files.pythonhosted.org/packages/8c/a2/0d269db0f6163be503775dc8b6a6fa15820cc9fdc866f6ba608d86b721f2/httplib2-0.31.0-py3-none-any.whl.metadata
#   Using cached httplib2-0.31.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting google-auth-httplib2<1.0.0,>=0.2.0 (from google-api-python-client==2.187.0->-r ./requirements.txt (line 6))
#   Obtaining dependency information for google-auth-httplib2<1.0.0,>=0.2.0 from https://files.pythonhosted.org/packages/44/a7/ca23dd006255f70e2bc469d3f9f0c82ea455335bfd682ad4d677adc435de/google_auth_httplib2-0.2.1-py3-none-any.whl.metadata
#   Using cached google_auth_httplib2-0.2.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 (from google-api-python-client==2.187.0->-r ./requirements.txt (line 6))
#   Obtaining dependency information for google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 from https://files.pythonhosted.org/packages/ed/d4/90197b416cb61cefd316964fd9e7bd8324bcbafabf40eef14a9f20b81974/google_api_core-2.28.1-py3-none-any.whl.metadata
#   Using cached google_api_core-2.28.1-py3-none-any.whl.metadata (3.3 kB)
# Collecting uritemplate<5,>=3.0.1 (from google-api-python-client==2.187.0->-r ./requirements.txt (line 6))
#   Obtaining dependency information for uritemplate<5,>=3.0.1 from https://files.pythonhosted.org/packages/a9/99/3ae339466c9183ea5b8ae87b34c0b897eda475d2aec2307cae60e5cd4f29/uritemplate-4.2.0-py3-none-any.whl.metadata
#   Using cached uritemplate-4.2.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting bcrypt>=3.2 (from paramiko==4.0.0->-r ./requirements.txt (line 8))
#   Obtaining dependency information for bcrypt>=3.2 from https://files.pythonhosted.org/packages/d4/8d/5e43d9584b3b3591a6f9b68f755a4da879a59712981ef5ad2a0ac1379f7a/bcrypt-5.0.0-cp39-abi3-manylinux_2_34_x86_64.whl.metadata
#   Using cached bcrypt-5.0.0-cp39-abi3-manylinux_2_34_x86_64.whl.metadata (10 kB)
# Collecting cryptography>=3.3 (from paramiko==4.0.0->-r ./requirements.txt (line 8))
#   Obtaining dependency information for cryptography>=3.3 from https://files.pythonhosted.org/packages/8f/29/798fc4ec461a1c9e9f735f2fc58741b0daae30688f41b2497dcbc9ed1355/cryptography-46.0.3-cp311-abi3-manylinux_2_34_x86_64.whl.metadata
#   Using cached cryptography-46.0.3-cp311-abi3-manylinux_2_34_x86_64.whl.metadata (5.7 kB)
# Collecting invoke>=2.0 (from paramiko==4.0.0->-r ./requirements.txt (line 8))
#   Obtaining dependency information for invoke>=2.0 from https://files.pythonhosted.org/packages/32/4b/b99e37f88336009971405cbb7630610322ed6fbfa31e1d7ab3fbf3049a2d/invoke-2.2.1-py3-none-any.whl.metadata
#   Using cached invoke-2.2.1-py3-none-any.whl.metadata (3.3 kB)
# Collecting pynacl>=1.5 (from paramiko==4.0.0->-r ./requirements.txt (line 8))
#   Obtaining dependency information for pynacl>=1.5 from https://files.pythonhosted.org/packages/a8/6c/dd9ee8214edf63ac563b08a9b30f98d116942b621d39a751ac3256694536/pynacl-1.6.1-cp38-abi3-manylinux_2_34_x86_64.whl.metadata
#   Using cached pynacl-1.6.1-cp38-abi3-manylinux_2_34_x86_64.whl.metadata (9.8 kB)
# Collecting urllib3!=2.2.0,<3,>=1.25.4 (from botocore<1.42.0,>=1.41.5->boto3==1.41.5->-r ./requirements.txt (line 3))
#   Obtaining dependency information for urllib3!=2.2.0,<3,>=1.25.4 from https://files.pythonhosted.org/packages/a7/c2/fe1e52489ae3122415c51f387e221dd0773709bad6c6cdaa599e8a2c5185/urllib3-2.5.0-py3-none-any.whl.metadata
#   Using cached urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting cffi>=2.0.0 (from cryptography>=3.3->paramiko==4.0.0->-r ./requirements.txt (line 8))
#   Obtaining dependency information for cffi>=2.0.0 from https://files.pythonhosted.org/packages/d7/91/500d892b2bf36529a75b77958edfcd5ad8e2ce4064ce2ecfeab2125d72d1/cffi-2.0.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata
#   Using cached cffi-2.0.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.6 kB)
# Collecting googleapis-common-protos<2.0.0,>=1.56.2 (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client==2.187.0->-r ./requirements.txt (line 6))
#   Obtaining dependency information for googleapis-common-protos<2.0.0,>=1.56.2 from https://files.pythonhosted.org/packages/c4/ab/09169d5a4612a5f92490806649ac8d41e3ec9129c636754575b3553f4ea4/googleapis_common_protos-1.72.0-py3-none-any.whl.metadata
#   Using cached googleapis_common_protos-1.72.0-py3-none-any.whl.metadata (9.4 kB)
# Collecting protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client==2.187.0->-r ./requirements.txt (line 6))
#   Obtaining dependency information for protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 from https://files.pythonhosted.org/packages/1d/2a/3c5f05a4af06649547027d288747f68525755de692a26a7720dced3652c0/protobuf-6.33.1-cp39-abi3-manylinux2014_x86_64.whl.metadata
#   Using cached protobuf-6.33.1-cp39-abi3-manylinux2014_x86_64.whl.metadata (593 bytes)
# Collecting proto-plus<2.0.0,>=1.22.3 (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client==2.187.0->-r ./requirements.txt (line 6))
#   Obtaining dependency information for proto-plus<2.0.0,>=1.22.3 from https://files.pythonhosted.org/packages/4e/6d/280c4c2ce28b1593a19ad5239c8b826871fc6ec275c21afc8e1820108039/proto_plus-1.26.1-py3-none-any.whl.metadata
#   Using cached proto_plus-1.26.1-py3-none-any.whl.metadata (2.2 kB)
# Collecting requests<3.0.0,>=2.18.0 (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client==2.187.0->-r ./requirements.txt (line 6))
#   Obtaining dependency information for requests<3.0.0,>=2.18.0 from https://files.pythonhosted.org/packages/1e/db/4254e3eabe8020b458f1a747140d32277ec7a271daf1d235b70dc0b4e6e3/requests-2.32.5-py3-none-any.whl.metadata
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting cachetools<7.0,>=2.0.0 (from google-auth<2.42.0,>=2.15.0->google-auth-oauthlib==1.2.3->-r ./requirements.txt (line 5))
#   Obtaining dependency information for cachetools<7.0,>=2.0.0 from https://files.pythonhosted.org/packages/e6/46/eb6eca305c77a4489affe1c5d8f4cae82f285d9addd8de4ec084a7184221/cachetools-6.2.2-py3-none-any.whl.metadata
#   Using cached cachetools-6.2.2-py3-none-any.whl.metadata (5.6 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<2.42.0,>=2.15.0->google-auth-oauthlib==1.2.3->-r ./requirements.txt (line 5))
#   Obtaining dependency information for pyasn1-modules>=0.2.1 from https://files.pythonhosted.org/packages/47/8d/d529b5d697919ba8c11ad626e835d4039be708a35b0d22de83a269a6682c/pyasn1_modules-0.4.2-py3-none-any.whl.metadata
#   Using cached pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth<2.42.0,>=2.15.0->google-auth-oauthlib==1.2.3->-r ./requirements.txt (line 5))
#   Obtaining dependency information for rsa<5,>=3.1.4 from https://files.pythonhosted.org/packages/64/8d/0133e4eb4beed9e425d9a98ed6e081a55d195481b7632472be1af08d2f6b/rsa-4.9.1-py3-none-any.whl.metadata
#   Using cached rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting pyparsing<4,>=3.0.4 (from httplib2<1.0.0,>=0.19.0->google-api-python-client==2.187.0->-r ./requirements.txt (line 6))
#   Obtaining dependency information for pyparsing<4,>=3.0.4 from https://files.pythonhosted.org/packages/10/5e/1aa9a93198c6b64513c9d7752de7422c06402de6600a8767da1524f9570b/pyparsing-3.2.5-py3-none-any.whl.metadata
#   Using cached pyparsing-3.2.5-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: decorator>=4.3.2 in /home/leonardooliveira/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel==7.1.0->-r ./requirements.txt (line 1)) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /home/leonardooliveira/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel==7.1.0->-r ./requirements.txt (line 1)) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in /home/leonardooliveira/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel==7.1.0->-r ./requirements.txt (line 1)) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /home/leonardooliveira/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel==7.1.0->-r ./requirements.txt (line 1)) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/leonardooliveira/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel==7.1.0->-r ./requirements.txt (line 1)) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in /home/leonardooliveira/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel==7.1.0->-r ./requirements.txt (line 1)) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in /home/leonardooliveira/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel==7.1.0->-r ./requirements.txt (line 1)) (0.6.3)
# Requirement already satisfied: typing_extensions>=4.6 in /home/leonardooliveira/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel==7.1.0->-r ./requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: platformdirs>=2.5 in /home/leonardooliveira/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel==7.1.0->-r ./requirements.txt (line 1)) (4.5.0)
# Requirement already satisfied: six>=1.5 in /home/leonardooliveira/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas==2.2.3->-r ./requirements.txt (line 4)) (1.17.0)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->google-auth-oauthlib==1.2.3->-r ./requirements.txt (line 5))
#   Obtaining dependency information for oauthlib>=3.0.0 from https://files.pythonhosted.org/packages/be/9c/92789c596b8df838baa98fa71844d84283302f7604ed565dafe5a6b5041a/oauthlib-3.3.1-py3-none-any.whl.metadata
#   Using cached oauthlib-3.3.1-py3-none-any.whl.metadata (7.9 kB)
# Collecting pycparser (from cffi>=2.0.0->cryptography>=3.3->paramiko==4.0.0->-r ./requirements.txt (line 8))
#   Obtaining dependency information for pycparser from https://files.pythonhosted.org/packages/a0/e3/59cd50310fc9b59512193629e1984c1f95e5c8ae6e5d8c69532ccc65a7fe/pycparser-2.23-py3-none-any.whl.metadata
#   Using cached pycparser-2.23-py3-none-any.whl.metadata (993 bytes)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/leonardooliveira/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from jedi>=0.18.1->ipython>=7.23.1->ipykernel==7.1.0->-r ./requirements.txt (line 1)) (0.8.5)
# Requirement already satisfied: ptyprocess>=0.5 in /home/leonardooliveira/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel==7.1.0->-r ./requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: wcwidth in /home/leonardooliveira/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel==7.1.0->-r ./requirements.txt (line 1)) (0.2.14)
# Collecting pyasn1<0.7.0,>=0.6.1 (from pyasn1-modules>=0.2.1->google-auth<2.42.0,>=2.15.0->google-auth-oauthlib==1.2.3->-r ./requirements.txt (line 5))
#   Obtaining dependency information for pyasn1<0.7.0,>=0.6.1 from https://files.pythonhosted.org/packages/c8/f1/d6a797abb14f6283c0ddff96bbdd46937f64122b8c925cab503dd37f8214/pyasn1-0.6.1-py3-none-any.whl.metadata
#   Using cached pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Collecting charset_normalizer<4,>=2 (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client==2.187.0->-r ./requirements.txt (line 6))
#   Obtaining dependency information for charset_normalizer<4,>=2 from https://files.pythonhosted.org/packages/6d/fc/de9cce525b2c5b94b47c70a4b4fb19f871b24995c728e957ee68ab1671ea/charset_normalizer-3.4.4-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata
#   Using cached charset_normalizer-3.4.4-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (37 kB)
# Collecting idna<4,>=2.5 (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client==2.187.0->-r ./requirements.txt (line 6))
#   Obtaining dependency information for idna<4,>=2.5 from https://files.pythonhosted.org/packages/0e/61/66938bbb5fc52dbdf84594873d5b51fb1f7c7794e9c0f5bd885f30bc507b/idna-3.11-py3-none-any.whl.metadata
#   Using cached idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting certifi>=2017.4.17 (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client==2.187.0->-r ./requirements.txt (line 6))
#   Obtaining dependency information for certifi>=2017.4.17 from https://files.pythonhosted.org/packages/70/7d/9bc192684cea499815ff478dfcdc13835ddf401365057044fb721ec6bddb/certifi-2025.11.12-py3-none-any.whl.metadata
#   Using cached certifi-2025.11.12-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: executing>=1.2.0 in /home/leonardooliveira/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel==7.1.0->-r ./requirements.txt (line 1)) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/leonardooliveira/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel==7.1.0->-r ./requirements.txt (line 1)) (3.0.1)
# Requirement already satisfied: pure-eval in /home/leonardooliveira/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel==7.1.0->-r ./requirements.txt (line 1)) (0.2.3)
# Using cached boto3-1.41.5-py3-none-any.whl (139 kB)
# Using cached pandas-2.2.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.1 MB)
# Using cached google_auth_oauthlib-1.2.3-py3-none-any.whl (19 kB)
# Using cached google_api_python_client-2.187.0-py3-none-any.whl (14.6 MB)
# Using cached paramiko-4.0.0-py3-none-any.whl (223 kB)
# Using cached py4j-0.10.9.7-py2.py3-none-any.whl (200 kB)
# Using cached bcrypt-5.0.0-cp39-abi3-manylinux_2_34_x86_64.whl (278 kB)
# Using cached botocore-1.41.6-py3-none-any.whl (14.4 MB)
# Using cached cryptography-46.0.3-cp311-abi3-manylinux_2_34_x86_64.whl (4.5 MB)
# Using cached google_api_core-2.28.1-py3-none-any.whl (173 kB)
# Using cached google_auth-2.41.1-py2.py3-none-any.whl (221 kB)
# Using cached google_auth_httplib2-0.2.1-py3-none-any.whl (9.5 kB)
# Using cached httplib2-0.31.0-py3-none-any.whl (91 kB)
# Using cached invoke-2.2.1-py3-none-any.whl (160 kB)
# Using cached jmespath-1.0.1-py3-none-any.whl (20 kB)
# Using cached numpy-2.3.5-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.9 MB)
# Using cached pynacl-1.6.1-cp38-abi3-manylinux_2_34_x86_64.whl (1.4 MB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Using cached s3transfer-0.15.0-py3-none-any.whl (85 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Using cached uritemplate-4.2.0-py3-none-any.whl (11 kB)
# Using cached cachetools-6.2.2-py3-none-any.whl (11 kB)
# Using cached cffi-2.0.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (215 kB)
# Using cached googleapis_common_protos-1.72.0-py3-none-any.whl (297 kB)
# Using cached oauthlib-3.3.1-py3-none-any.whl (160 kB)
# Using cached proto_plus-1.26.1-py3-none-any.whl (50 kB)
# Using cached protobuf-6.33.1-cp39-abi3-manylinux2014_x86_64.whl (323 kB)
# Using cached pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Using cached pyparsing-3.2.5-py3-none-any.whl (113 kB)
# Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Using cached rsa-4.9.1-py3-none-any.whl (34 kB)
# Using cached urllib3-2.5.0-py3-none-any.whl (129 kB)
# Using cached certifi-2025.11.12-py3-none-any.whl (159 kB)
# Using cached charset_normalizer-3.4.4-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (151 kB)
# Using cached idna-3.11-py3-none-any.whl (71 kB)
# Using cached pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Using cached pycparser-2.23-py3-none-any.whl (118 kB)
# Installing collected packages: pytz, pysftpserver, py4j, urllib3, uritemplate, tzdata, pyspark, pyparsing, pycparser, pyasn1, protobuf, oauthlib, numpy, jmespath, invoke, idna, charset_normalizer, certifi, cachetools, bcrypt, rsa, requests, pyasn1-modules, proto-plus, pandas, httplib2, googleapis-common-protos, cffi, botocore, s3transfer, requests-oauthlib, pynacl, google-auth, cryptography, paramiko, google-auth-oauthlib, google-auth-httplib2, google-api-core, boto3, google-api-python-client
# Successfully installed bcrypt-5.0.0 boto3-1.41.5 botocore-1.41.6 cachetools-6.2.2 certifi-2025.11.12 cffi-2.0.0 charset_normalizer-3.4.4 cryptography-46.0.3 google-api-core-2.28.1 google-api-python-client-2.187.0 google-auth-2.41.1 google-auth-httplib2-0.2.1 google-auth-oauthlib-1.2.3 googleapis-common-protos-1.72.0 httplib2-0.31.0 idna-3.11 invoke-2.2.1 jmespath-1.0.1 numpy-2.3.5 oauthlib-3.3.1 pandas-2.2.3 paramiko-4.0.0 proto-plus-1.26.1 protobuf-6.33.1 py4j-0.10.9.7 pyasn1-0.6.1 pyasn1-modules-0.4.2 pycparser-2.23 pynacl-1.6.1 pyparsing-3.2.5 pysftpserver-1.4.0 pyspark-3.5.7 pytz-2025.2 requests-2.32.5 requests-oauthlib-2.0.0 rsa-4.9.1 s3transfer-0.15.0 tzdata-2025.2 uritemplate-4.2.0 urllib3-2.5.0
#
# [notice] A new release of pip is available: 23.2.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from pyspark.sql import SparkSession, DataFrame
from pyspark.sql.functions import col, count, max, add_months, to_timestamp
from typing import Dict, List
from functools import reduce
import boto3

# %%
def create_spark_session():
        """
        Create and return a Spark session configured for AWS S3 access.
        Returns:
            SparkSession: Configured Spark session object.
        """
        aws_profile_name = "default"

        spark = SparkSession.builder \
                            .appName("SplitColumnExample") \
                            .config(
                                "spark.jars.packages",
                                "org.apache.hadoop:hadoop-aws:3.3.4,"
                                "com.amazonaws:aws-java-sdk-bundle:1.12.262"
                            ) \
                            .config(
                                "spark.hadoop.fs.s3a.aws.credentials.provider",
                                "com.amazonaws.auth.profile.ProfileCredentialsProvider"
                            ) \
                            .config("spark.hadoop.fs.s3a.profile", aws_profile_name) \
                            .getOrCreate()
        
        return spark

# %%
def get_s3_data(spark: SparkSession, combine_paths_to_df: bool = True, s3_scheme: str = "s3a"):
    """
    Traverses page_iterator (response from list_objects_v2 / boto3 paginator), groups file paths by table name (taking the element at table_index of the Key split by /),and reads the parquet files of each table into a DataFrame.
    Args:
        spark (SparkSession): Configured Spark session object.
        combine_paths_to_df (boolean, optional): If True, returns DataFrames; if False, returns only lists of paths.
        s3_scheme (string, optional): Scheme used to build the S3 path (e.g., "s3a" or "s3n" — default "s3a").
    Returns:
        tables_dfs (Dict): A dict where the key is the table name and the value is a DataFrame (or a list of paths if combine_paths_to_df=False).
    """

    s3 = boto3.client('s3')
    bucket_name = "data-challenge-loadsmart"
    bucket_prefix = "athena/loadsmart_analytics/"

    paginator = s3.get_paginator('list_objects_v2')
    page_iterator = paginator.paginate(Bucket=bucket_name, Prefix=bucket_prefix)

    table_paths: Dict[str, List[str]] = {}

    for page in page_iterator:
        if 'Contents' in page:
            for obj in page['Contents']:
                print(obj['Key'])
                data_path = f"{s3_scheme}://{bucket_name}/{obj['Key']}"
                parts = obj['Key'].split('/')
                table_name = parts[2]
                table_paths.setdefault(table_name, []).append(data_path)
    if not combine_paths_to_df:
        return table_paths
    
    tables_dfs: Dict[str, DataFrame] = {}

    for table, paths in table_paths.items():
        try:
            df = spark.read.parquet(*paths)
            tables_dfs[table] = df
        except Exception as e:
            print(f"Error to read paths combined for the table '{table}': {e}")
            print("Trying to read file a file and unite them by unionByName...")
            dfs = []
            for p in paths:
                try:
                    dfs.append(spark.read.parquet(p))
                except Exception as e:
                    print(f"Error by reading {p}: {e} (skipping this file)")
            try:
                combined = reduce(lambda a,b: a.unionByName(b, allowMissingColumns=True), dfs)
            except TypeError:
                combined = reduce(lambda a,b: a.unionByName(b), dfs)
            tables_dfs[table] = combined

    return tables_dfs

# %%
spark = create_spark_session()
dfs_por_tabela = get_s3_data(spark)
# Out:
# athena/loadsmart_analytics/dim_book/52312e26-fd1f-4eaa-b73a-c5742203cb8f/20251203_051343_00016_ydp5s_7e891e4d-aa78-4bcb-979b-1f04fe7938e2
# athena/loadsmart_analytics/dim_carriers/6785e746-bb04-4227-b3ef-3cb4f7698f4e/20251203_045540_00052_59x32_6acc931a-6655-4893-a294-3539e6a1d77e
# athena/loadsmart_analytics/dim_delivery/3e7d0e7e-1a19-43b0-a7de-b42613b212e4/20251203_045554_00223_hji59_83e25cf3-4ed8-4442-a881-399f0445b8af
# athena/loadsmart_analytics/dim_pickup/ec49864a-38aa-4751-938d-ca242517d7dd/20251203_045608_00268_8zxb3_cf76baa5-5127-46d9-91c5-5f5bab5f20e1
# athena/loadsmart_analytics/dim_shippers/a70754e1-a02d-4629-99fe-9f3b862503ad/20251203_045616_00061_aazau_54f56ec1-783a-46df-a843-87ed58a10411
# athena/loadsmart_analytics/fact_loadsmart/19c70d10-22e8-49de-8d39-1538b7f80296/20251203_052917_00214_hi6mf_43566975-95d1-4db2-a44d-eed7bcea12c9

# %%
dfs_por_tabela.keys()
# Out:
# dict_keys(['dim_book', 'dim_carriers', 'dim_delivery', 'dim_pickup', 'dim_shippers', 'fact_loadsmart'])

# %%
df_book = dfs_por_tabela["dim_book"]
df_book.show()
# Out:
# [Stage 21:>                                                         (0 + 1) / 1]
# +------------+-------------------+-------------------+-------------------+----------+------------+-------------------------+-------------------------+-----------------------+----------------+---------------+------------------------+-------------------------+------------------+
# |loadsmart_id|         quote_date|          book_date|        source_date|book_price|source_price|has_mobile_app_tracking23|has_mobile_app_tracking24|has_macropoint_tracking|has_edi_tracking|contracted_load|load_booked_autonomously|load_sourced_autonomously|load_was_cancelled|
# +------------+-------------------+-------------------+-------------------+----------+------------+-------------------------+-------------------------+-----------------------+----------------+---------------+------------------------+-------------------------+------------------+
# |   206431033|2024-12-15 13:08:00|2024-12-15 13:09:00|2024-12-15 13:44:00|   8922.51|      8500.0|                    false|                    false|                  false|           false|          false|                   false|                    false|             false|
# |   206521177|2024-11-20 09:32:00|2024-11-20 09:32:00|2024-11-21 09:46:00|   8726.17|      4000.0|                    false|                    false|                  false|           false|          false|                   false|                    false|             false|
# |   206694049|2024-06-01 18:04:00|2024-06-01 18:04:00|2024-06-02 15:11:00|   8548.19|      8220.0|                    false|                    false|                  false|           false|          false|                   false|                    false|             false|
# |   206426897|2024-05-18 17:16:00|2024-05-18 17:16:00|2024-05-22 11:45:00|   7475.63|      7500.0|                    false|                    false|                  false|           false|          false|                   false|                    false|             false|
# |   206512777|2024-11-05 19:46:00|2024-11-05 19:46:00|2024-11-06 12:37:00|   7409.97|      5000.0|                    false|                    false|                  false|           false|          false|                   false|                    false|             false|
# |   206437137|2024-12-04 17:01:00|2024-12-04 17:01:00|2024-12-07 16:41:00|   7402.38|      7500.0|                    false|                    false|                  false|           false|          false|                   false|                    false|             false|
# |   206513177|2024-12-28 19:43:00|2024-12-28 19:43:00|2025-01-02 16:38:00|   7371.42|      7500.0|                    false|                    false|                  false|           false|          false|                   false|                    false|             false|
# |   206709073|2024-10-05 10:56:00|2024-10-05 10:56:00|2024-10-06 12:57:00|    7250.0|      7000.0|                    false|                    false|                  false|           false|          false|                   false|                    false|             false|
# |   206554409|2024-10-24 08:45:00|2024-10-24 08:45:00|2024-10-24 11:16:00|   7232.42|         0.0|                    false|                    false|                  false|           false|          false|                   false|                    false|             false|
# |   206506609|2024-11-03 15:05:00|2024-11-03 15:06:00|2024-11-14 09:41:00|   7144.96|      9500.0|                    false|                    false|                  false|           false|          false|                   false|                    false|             false|
# |   206516521|2024-12-12 16:49:00|2024-12-12 16:49:00|2024-12-15 15:45:00|   7110.37|      7200.0|                    false|                    false|                  false|           false|          false|                   false|                    false|             false|
# |   206428753|2024-12-05 16:39:00|2024-12-05 16:39:00|2024-12-06 09:10:00|   7079.49|      6700.0|                    false|                    false|                  false|           false|          false|                   false|                    false|             false|
# |   206727809|2024-12-29 16:41:00|2024-12-29 16:41:00|2025-01-04 10:10:00|   7059.08|      6200.0|                    false|                    false|                  false|           false|          false|                   false|                    false|             false|
# |   206579337|2024-10-05 10:59:00|2024-10-05 10:59:00|2024-10-05 14:17:00|    7000.0|      6000.0|                    false|                    false|                  false|           false|          false|                   false|                    false|             false|
# |   206504865|2024-01-30 13:41:00|2024-01-30 13:41:00|2024-02-01 09:20:00|   6935.77|      6500.0|                    false|                    false|                  false|           false|          false|                   false|                    false|             false|
# |   206535497|2024-09-12 12:41:00|2024-09-12 12:41:00|2024-09-14 12:55:00|    6900.0|      6600.0|                    false|                    false|                  false|           false|          false|                   false|                    false|             false|
# |   206466833|2024-09-12 12:32:00|2024-09-12 12:32:00|2024-09-13 11:29:00|    6900.0|      6500.0|                    false|                    false|                  false|           false|          false|                   false|                    false|             false|
# |   206658377|2024-09-12 18:11:00|2024-09-12 18:11:00|2024-09-14 13:01:00|    6900.0|      6700.0|                    false|                    false|                  false|           false|          false|                   false|                    false|             false|
# |   206491073|2024-09-12 12:27:00|2024-09-12 12:27:00|2024-09-13 11:44:00|    6900.0|      6500.0|                    false|                    false|                  false|           false|          false|                   false|                    false|             false|
# |   206754337|2024-12-29 12:07:00|2024-12-29 12:07:00|2025-01-02 13:56:00|    7928.8|      6000.0|                    false|                    false|                  false|           false|          false|                   false|                    false|             false|
# +------------+-------------------+-------------------+-------------------+----------+------------+-------------------------+-------------------------+-----------------------+----------------+---------------+------------------------+-------------------------+------------------+
# only showing top 20 rows

# %%
df_book.count()
# Out:
# 5361

# %%
df_carriers = dfs_por_tabela["dim_carriers"]
df_carriers.show()
# Out:
# [Stage 25:>                                                         (0 + 1) / 1]
# +------------+--------------+-----------+------------------------+---------------+-------------------------+---------------------------+-----------------------+
# |loadsmart_id|carrier_rating|vip_carrier|carrier_dropped_us_count|   carrier_name|carrier_on_time_to_pickup|carrier_on_time_to_delivery|carrier_on_time_overall|
# +------------+--------------+-----------+------------------------+---------------+-------------------------+---------------------------+-----------------------+
# |   206431033|          NULL|      false|                       0| Carrier 605817|                     true|                       true|                   true|
# |   206521177|          NULL|      false|                       0|Carrier 1396487|                     true|                       true|                   true|
# |   206694049|          NULL|      false|                       0|Carrier 1044585|                     true|                       true|                   true|
# |   206553113|          NULL|      false|                       0|    Carrier 738|                     true|                       true|                   true|
# |   206518817|          NULL|      false|                       0|  Carrier 14533|                     true|                       true|                   true|
# |   206427025|          NULL|      false|                       0|Carrier 1695246|                     true|                       true|                   true|
# |   206478177|          NULL|      false|                       0| Carrier 968589|                     true|                       true|                   true|
# |   206754337|          NULL|      false|                       0|Carrier 1695502|                     true|                       true|                   true|
# |   206424601|          NULL|      false|                       0|    Carrier 738|                     true|                       true|                   true|
# |   206554617|          NULL|      false|                       0|    Carrier 738|                     true|                       true|                   true|
# |   206486537|          NULL|      false|                       1| Carrier 749107|                     true|                       true|                   true|
# |   206432441|          NULL|      false|                       0|Carrier 1049651|                     true|                       true|                   true|
# |   206490537|          NULL|       true|                       0|Carrier 1229009|                     true|                       true|                   true|
# |   206429353|          NULL|      false|                       0|Carrier 1019564|                    false|                       true|                   true|
# |   206558993|          NULL|      false|                       0|Carrier 1027120|                     true|                       true|                   true|
# |   206426897|          NULL|      false|                       1|Carrier 1695273|                     true|                       true|                   true|
# |   206512777|          NULL|      false|                       0|Carrier 1058714|                     true|                       true|                   true|
# |   206437137|          NULL|      false|                       1|Carrier 1695748|                    false|                       true|                  false|
# |   206513177|          NULL|      false|                       0|Carrier 1333902|                     true|                       true|                   true|
# |   206709073|          NULL|      false|                       0|Carrier 1695547|                     true|                       true|                   true|
# +------------+--------------+-----------+------------------------+---------------+-------------------------+---------------------------+-----------------------+
# only showing top 20 rows

# %%
df_carriers.count()
# Out:
# 5361

# %%
df_delivery = dfs_por_tabela["dim_delivery"]
df_delivery.show()
# Out:
# [Stage 29:>                                                         (0 + 1) / 1]
# +------------+--------------+--------------+-------------------+-------------------------+
# |loadsmart_id| delivery_city|delivery_state|      delivery_date|delivery_appointment_time|
# +------------+--------------+--------------+-------------------+-------------------------+
# |   206431033|Upper Marlboro|            MD|2024-12-21 02:00:00|      2024-12-21 00:00:00|
# |   206521177|          Reno|            NV|2024-11-27 16:00:00|      2024-11-27 17:00:00|
# |   206694049|Upper Marlboro|            MD|2024-06-09 04:10:00|      2024-06-08 23:00:00|
# |   206553113|          Reno|            NV|2024-11-28 19:00:00|      2024-11-28 19:00:00|
# |   206518817|      Portland|            OR|2024-10-02 11:55:00|      2024-10-02 10:00:00|
# |   206427025|      Portland|            OR|2025-01-04 12:00:00|      2024-12-29 14:00:00|
# |   206478177|      Portland|            OR|2024-11-03 10:00:00|      2024-11-03 12:00:00|
# |   206754337|      Portland|            OR|2025-01-05 03:10:00|      2025-01-05 01:00:00|
# |   206424601|          Reno|            NV|2024-11-27 13:30:00|      2024-11-27 17:00:00|
# |   206554617|          Reno|            NV|2024-11-28 19:00:00|      2024-11-28 19:00:00|
# |   206486537|    Plant City|            FL|2024-10-03 10:00:00|      2024-10-03 11:00:00|
# |   206432441|          Reno|            NV|2024-12-26 13:34:00|      2024-12-26 12:00:00|
# |   206490537|      Portland|            OR|2024-10-23 14:30:00|      2024-10-23 09:00:00|
# |   206429353|    Plant City|            FL|2024-10-09 12:30:00|      2024-10-09 10:00:00|
# |   206558993|Upper Marlboro|            MD|2024-05-25 23:55:00|      2024-05-25 23:00:00|
# |   206426897|Upper Marlboro|            MD|2024-05-25 23:55:00|      2024-05-25 23:00:00|
# |   206512777|      Portland|            OR|2024-11-17 17:00:00|      2024-11-14 18:00:00|
# |   206437137|        Newark|            NJ|2024-12-12 05:00:00|      2024-12-12 04:00:00|
# |   206513177|Upper Marlboro|            MD|2025-01-08 08:03:00|      2025-01-08 04:00:00|
# |   206709073|    Plant City|            FL|2024-10-12 09:00:00|      2024-10-12 08:00:00|
# +------------+--------------+--------------+-------------------+-------------------------+
# only showing top 20 rows

# %%
df_delivery.count()
# Out:
# 5361

# %%
df_pickup = dfs_por_tabela["dim_pickup"]
df_pickup.show()
# Out:
# [Stage 33:>                                                         (0 + 1) / 1]
# +------------+-----------+------------+-------------------+-----------------------+
# |loadsmart_id|pickup_city|pickup_state|        pickup_date|pickup_appointment_time|
# +------------+-----------+------------+-------------------+-----------------------+
# |   206431033| Hood River|          OR|2024-12-15 11:00:00|    2024-12-15 20:00:00|
# |   206521177|     Etowah|          TN|2024-11-21 14:00:00|    2024-11-21 14:00:00|
# |   206694049|    Salinas|          CA|2024-06-03 02:00:00|    2024-06-03 02:00:00|
# |   206553113| Montpelier|          OH|2024-11-22 17:00:00|    2024-11-22 17:00:00|
# |   206518817|     Newark|          DE|2024-09-26 17:00:00|    2024-09-26 17:00:00|
# |   206427025|     Maxton|          NC|2024-12-23 15:00:00|    2024-12-23 15:00:00|
# |   206478177|     Maxton|          NC|2024-10-31 14:00:00|    2024-10-31 14:00:00|
# |   206754337|    Manning|          SC|2025-01-03 08:00:00|    2025-01-03 09:00:00|
# |   206424601| Montpelier|          OH|2024-11-21 13:00:00|    2024-11-21 13:00:00|
# |   206554617| Montpelier|          OH|2024-11-22 12:00:00|    2024-11-22 12:00:00|
# |   206486537|  Santa Ana|          CA|2024-09-29 16:00:00|    2024-09-29 22:00:00|
# |   206432441|    Trenton|          MO|2024-12-22 16:00:00|    2024-12-22 16:00:00|
# |   206490537|     Maxton|          NC|2024-10-19 14:00:00|    2024-10-19 14:00:00|
# |   206429353|  Santa Ana|          CA|2024-10-06 12:00:00|    2024-10-06 12:00:00|
# |   206558993|    Salinas|          CA|2024-05-20 13:00:00|    2024-05-20 13:00:00|
# |   206426897|   Gonzales|          CA|2024-05-22 11:00:00|    2024-05-23 00:00:00|
# |   206512777|   Lakewood|          NY|2024-11-10 15:00:00|    2024-11-10 15:00:00|
# |   206437137|  Fairfield|          CA|2024-12-07 15:00:00|    2024-12-07 15:00:00|
# |   206513177|     Yakima|          WA|2025-01-03 11:00:00|    2025-01-03 15:00:00|
# |   206709073|  Santa Ana|          CA|2024-10-09 15:00:00|    2024-10-09 15:00:00|
# +------------+-----------+------------+-------------------+-----------------------+
# only showing top 20 rows

# %%
df_pickup.count()
# Out:
# 5361

# %%
df_shippers = dfs_por_tabela["dim_shippers"]
df_shippers.show()
# Out:
# [Stage 37:>                                                         (0 + 1) / 1]
# +------------+--------+-------+--------------+----------------+------------+
# |loadsmart_id|     pnl|mileage|equipment_type|sourcing_channel|shipper_name|
# +------------+--------+-------+--------------+----------------+------------+
# |   206431033|  422.51| 2753.5|           RFR|          dat_in| Shipper 758|
# |   206426897|  -24.37| 2948.9|           RFR|            NULL| Shipper 758|
# |   206512777| 2409.97| 2591.7|           DRV|            NULL|Shipper 1644|
# |   206437137|  -97.62| 2847.9|           RFR|carrier_capacity|Shipper 1249|
# |   206513177| -128.58| 2702.1|           RFR|            NULL| Shipper 758|
# |   206709073|   250.0| 2509.6|           RFR|            NULL| Shipper 585|
# |   206554409|     0.0| 2777.3|           DRV|            NULL|Shipper 1644|
# |   206506609|-2355.04| 3069.0|           RFR|            NULL| Shipper 832|
# |   206516521|  -89.63| 2733.2|           RFR|            NULL|Shipper 1249|
# |   206428753|  379.49| 2733.2|           RFR|     source_list|Shipper 1249|
# |   206727809|  859.08| 1490.1|           RFR|          dat_in| Shipper 758|
# |   206579337|  1000.0| 2509.6|           RFR|            NULL| Shipper 585|
# |   206504865|  435.77| 3002.0|           RFR|            NULL| Shipper 832|
# |   206535497|   300.0| 2891.5|           RFR|            NULL|Shipper 1103|
# |   206466833|   400.0| 2891.5|           RFR|            NULL|Shipper 1103|
# |   206658377|   200.0| 2891.5|           RFR|            NULL|Shipper 1103|
# |   206491073|   400.0| 2891.5|           RFR|            NULL|Shipper 1103|
# |   206521177| 4726.17| 2331.3|           DRV|            NULL|Shipper 1644|
# |   206694049|  328.19| 3013.4|           RFR|            NULL| Shipper 758|
# |   206553113| 3409.27| 2082.3|           DRV|            NULL|Shipper 1644|
# +------------+--------+-------+--------------+----------------+------------+
# only showing top 20 rows

# %%
df_shippers.count()
# Out:
# 5361

# %%
df_loadsmart = dfs_por_tabela["fact_loadsmart"]
df_loadsmart.show()
# Out:
# [Stage 41:>                                                         (0 + 1) / 1]
# +------------+-------------------+-------------------+-------------------+----------+------------+--------------+------------------------+-------------------+-------------------------+-------------------+-----------------------+--------+-------+
# |loadsmart_id|         quote_date|          book_date|        source_date|book_price|source_price|carrier_rating|carrier_dropped_us_count|      delivery_date|delivery_appointment_time|        pickup_date|pickup_appointment_time|     pnl|mileage|
# +------------+-------------------+-------------------+-------------------+----------+------------+--------------+------------------------+-------------------+-------------------------+-------------------+-----------------------+--------+-------+
# |   206431033|2024-12-15 13:08:00|2024-12-15 13:09:00|2024-12-15 13:44:00|   8922.51|      8500.0|          NULL|                       0|2024-12-21 02:00:00|      2024-12-21 00:00:00|2024-12-15 11:00:00|    2024-12-15 20:00:00|  422.51| 2753.5|
# |   206521177|2024-11-20 09:32:00|2024-11-20 09:32:00|2024-11-21 09:46:00|   8726.17|      4000.0|          NULL|                       0|2024-11-27 16:00:00|      2024-11-27 17:00:00|2024-11-21 14:00:00|    2024-11-21 14:00:00| 4726.17| 2331.3|
# |   206694049|2024-06-01 18:04:00|2024-06-01 18:04:00|2024-06-02 15:11:00|   8548.19|      8220.0|          NULL|                       0|2024-06-09 04:10:00|      2024-06-08 23:00:00|2024-06-03 02:00:00|    2024-06-03 02:00:00|  328.19| 3013.4|
# |   206553113|2024-11-20 09:10:00|2024-11-20 09:10:00|2024-11-20 12:39:00|   8409.27|      5000.0|          NULL|                       0|2024-11-28 19:00:00|      2024-11-28 19:00:00|2024-11-22 17:00:00|    2024-11-22 17:00:00| 3409.27| 2082.3|
# |   206518817|2024-09-25 15:07:00|2024-09-25 15:07:00|2024-09-26 09:05:00|   8351.95|      5500.0|          NULL|                       0|2024-10-02 11:55:00|      2024-10-02 10:00:00|2024-09-26 17:00:00|    2024-09-26 17:00:00| 2851.95| 2847.7|
# |   206427025|2024-12-19 16:30:00|2024-12-19 16:30:00|2024-12-20 10:38:00|   8140.88|     11050.0|          NULL|                       0|2025-01-04 12:00:00|      2024-12-29 14:00:00|2024-12-23 15:00:00|    2024-12-23 15:00:00|-2909.12| 2863.1|
# |   206478177|2024-10-30 12:47:00|2024-10-30 12:47:00|2024-10-31 11:24:00|   7940.21|      6100.0|          NULL|                       0|2024-11-03 10:00:00|      2024-11-03 12:00:00|2024-10-31 14:00:00|    2024-10-31 14:00:00| 1840.21|    0.0|
# |   206754337|2024-12-29 12:07:00|2024-12-29 12:07:00|2025-01-02 13:56:00|    7928.8|      6000.0|          NULL|                       0|2025-01-05 03:10:00|      2025-01-05 01:00:00|2025-01-03 08:00:00|    2025-01-03 09:00:00|  1928.8| 2852.8|
# |   206424601|2024-11-20 09:00:00|2024-11-20 09:00:00|2024-11-20 12:33:00|   7784.82|      5000.0|          NULL|                       0|2024-11-27 13:30:00|      2024-11-27 17:00:00|2024-11-21 13:00:00|    2024-11-21 13:00:00| 2784.82| 2082.3|
# |   206554617|2024-11-20 09:21:00|2024-11-20 09:21:00|2024-11-20 12:33:00|   7784.82|      5000.0|          NULL|                       0|2024-11-28 19:00:00|      2024-11-28 19:00:00|2024-11-22 12:00:00|    2024-11-22 12:00:00| 2784.82| 2082.3|
# |   206486537|2024-09-28 11:26:00|2024-09-28 11:26:00|2024-09-29 19:21:00|    7700.0|      7500.0|          NULL|                       1|2024-10-03 10:00:00|      2024-10-03 11:00:00|2024-09-29 16:00:00|    2024-09-29 22:00:00|   200.0| 2509.6|
# |   206432441|2024-12-22 11:35:00|2024-12-22 11:35:00|2024-12-22 13:07:00|   7632.35|      6000.0|          NULL|                       0|2024-12-26 13:34:00|      2024-12-26 12:00:00|2024-12-22 16:00:00|    2024-12-22 16:00:00| 1632.35| 1607.7|
# |   206432441|2024-12-22 11:35:00|2024-12-22 11:35:00|2024-12-22 13:07:00|   7632.35|      6000.0|          NULL|                       0|2024-12-26 13:34:00|      2024-12-26 12:00:00|2024-12-22 16:00:00|    2024-12-22 16:00:00| 1632.35| 1607.7|
# |   206432441|2024-12-22 11:35:00|2024-12-22 11:35:00|2024-12-22 13:07:00|   7632.35|      6000.0|          NULL|                       0|2024-12-26 13:34:00|      2024-12-26 12:00:00|2024-12-22 16:00:00|    2024-12-22 16:00:00| 1632.35| 1607.7|
# |   206432441|2024-12-22 11:35:00|2024-12-22 11:35:00|2024-12-22 13:07:00|   7632.35|      6000.0|          NULL|                       0|2024-12-26 13:34:00|      2024-12-26 12:00:00|2024-12-22 16:00:00|    2024-12-22 16:00:00| 1632.35| 1607.7|
# |   206432441|2024-12-22 11:35:00|2024-12-22 11:35:00|2024-12-22 13:07:00|   7632.35|      6000.0|          NULL|                       0|2024-12-26 13:34:00|      2024-12-26 12:00:00|2024-12-22 16:00:00|    2024-12-22 16:00:00| 1632.35| 1607.7|
# |   206432441|2024-12-22 11:35:00|2024-12-22 11:35:00|2024-12-22 13:07:00|   7632.35|      6000.0|          NULL|                       0|2024-12-26 13:34:00|      2024-12-26 12:00:00|2024-12-22 16:00:00|    2024-12-22 16:00:00| 1632.35| 1607.7|
# |   206432441|2024-12-22 11:35:00|2024-12-22 11:35:00|2024-12-22 13:07:00|   7632.35|      6000.0|          NULL|                       0|2024-12-26 13:34:00|      2024-12-26 12:00:00|2024-12-22 16:00:00|    2024-12-22 16:00:00| 1632.35| 1607.7|
# |   206432441|2024-12-22 11:35:00|2024-12-22 11:35:00|2024-12-22 13:07:00|   7632.35|      6000.0|          NULL|                       0|2024-12-26 13:34:00|      2024-12-26 12:00:00|2024-12-22 16:00:00|    2024-12-22 16:00:00| 1632.35| 1607.7|
# |   206432441|2024-12-22 11:35:00|2024-12-22 11:35:00|2024-12-22 13:07:00|   7632.35|      6000.0|          NULL|                       0|2024-12-26 13:34:00|      2024-12-26 12:00:00|2024-12-22 16:00:00|    2024-12-22 16:00:00| 1632.35| 1607.7|
# +------------+-------------------+-------------------+-------------------+----------+------------+--------------+------------------------+-------------------+-------------------------+-------------------+-----------------------+--------+-------+
# only showing top 20 rows

# %%
df_loadsmart.show()
# Out:
# [Stage 42:>                                                         (0 + 1) / 1]
# +------------+-------------------+-------------------+-------------------+----------+------------+--------------+------------------------+-------------------+-------------------------+-------------------+-----------------------+--------+-------+
# |loadsmart_id|         quote_date|          book_date|        source_date|book_price|source_price|carrier_rating|carrier_dropped_us_count|      delivery_date|delivery_appointment_time|        pickup_date|pickup_appointment_time|     pnl|mileage|
# +------------+-------------------+-------------------+-------------------+----------+------------+--------------+------------------------+-------------------+-------------------------+-------------------+-----------------------+--------+-------+
# |   206431033|2024-12-15 13:08:00|2024-12-15 13:09:00|2024-12-15 13:44:00|   8922.51|      8500.0|          NULL|                       0|2024-12-21 02:00:00|      2024-12-21 00:00:00|2024-12-15 11:00:00|    2024-12-15 20:00:00|  422.51| 2753.5|
# |   206521177|2024-11-20 09:32:00|2024-11-20 09:32:00|2024-11-21 09:46:00|   8726.17|      4000.0|          NULL|                       0|2024-11-27 16:00:00|      2024-11-27 17:00:00|2024-11-21 14:00:00|    2024-11-21 14:00:00| 4726.17| 2331.3|
# |   206694049|2024-06-01 18:04:00|2024-06-01 18:04:00|2024-06-02 15:11:00|   8548.19|      8220.0|          NULL|                       0|2024-06-09 04:10:00|      2024-06-08 23:00:00|2024-06-03 02:00:00|    2024-06-03 02:00:00|  328.19| 3013.4|
# |   206553113|2024-11-20 09:10:00|2024-11-20 09:10:00|2024-11-20 12:39:00|   8409.27|      5000.0|          NULL|                       0|2024-11-28 19:00:00|      2024-11-28 19:00:00|2024-11-22 17:00:00|    2024-11-22 17:00:00| 3409.27| 2082.3|
# |   206518817|2024-09-25 15:07:00|2024-09-25 15:07:00|2024-09-26 09:05:00|   8351.95|      5500.0|          NULL|                       0|2024-10-02 11:55:00|      2024-10-02 10:00:00|2024-09-26 17:00:00|    2024-09-26 17:00:00| 2851.95| 2847.7|
# |   206427025|2024-12-19 16:30:00|2024-12-19 16:30:00|2024-12-20 10:38:00|   8140.88|     11050.0|          NULL|                       0|2025-01-04 12:00:00|      2024-12-29 14:00:00|2024-12-23 15:00:00|    2024-12-23 15:00:00|-2909.12| 2863.1|
# |   206478177|2024-10-30 12:47:00|2024-10-30 12:47:00|2024-10-31 11:24:00|   7940.21|      6100.0|          NULL|                       0|2024-11-03 10:00:00|      2024-11-03 12:00:00|2024-10-31 14:00:00|    2024-10-31 14:00:00| 1840.21|    0.0|
# |   206754337|2024-12-29 12:07:00|2024-12-29 12:07:00|2025-01-02 13:56:00|    7928.8|      6000.0|          NULL|                       0|2025-01-05 03:10:00|      2025-01-05 01:00:00|2025-01-03 08:00:00|    2025-01-03 09:00:00|  1928.8| 2852.8|
# |   206424601|2024-11-20 09:00:00|2024-11-20 09:00:00|2024-11-20 12:33:00|   7784.82|      5000.0|          NULL|                       0|2024-11-27 13:30:00|      2024-11-27 17:00:00|2024-11-21 13:00:00|    2024-11-21 13:00:00| 2784.82| 2082.3|
# |   206554617|2024-11-20 09:21:00|2024-11-20 09:21:00|2024-11-20 12:33:00|   7784.82|      5000.0|          NULL|                       0|2024-11-28 19:00:00|      2024-11-28 19:00:00|2024-11-22 12:00:00|    2024-11-22 12:00:00| 2784.82| 2082.3|
# |   206486537|2024-09-28 11:26:00|2024-09-28 11:26:00|2024-09-29 19:21:00|    7700.0|      7500.0|          NULL|                       1|2024-10-03 10:00:00|      2024-10-03 11:00:00|2024-09-29 16:00:00|    2024-09-29 22:00:00|   200.0| 2509.6|
# |   206432441|2024-12-22 11:35:00|2024-12-22 11:35:00|2024-12-22 13:07:00|   7632.35|      6000.0|          NULL|                       0|2024-12-26 13:34:00|      2024-12-26 12:00:00|2024-12-22 16:00:00|    2024-12-22 16:00:00| 1632.35| 1607.7|
# |   206432441|2024-12-22 11:35:00|2024-12-22 11:35:00|2024-12-22 13:07:00|   7632.35|      6000.0|          NULL|                       0|2024-12-26 13:34:00|      2024-12-26 12:00:00|2024-12-22 16:00:00|    2024-12-22 16:00:00| 1632.35| 1607.7|
# |   206432441|2024-12-22 11:35:00|2024-12-22 11:35:00|2024-12-22 13:07:00|   7632.35|      6000.0|          NULL|                       0|2024-12-26 13:34:00|      2024-12-26 12:00:00|2024-12-22 16:00:00|    2024-12-22 16:00:00| 1632.35| 1607.7|
# |   206432441|2024-12-22 11:35:00|2024-12-22 11:35:00|2024-12-22 13:07:00|   7632.35|      6000.0|          NULL|                       0|2024-12-26 13:34:00|      2024-12-26 12:00:00|2024-12-22 16:00:00|    2024-12-22 16:00:00| 1632.35| 1607.7|
# |   206432441|2024-12-22 11:35:00|2024-12-22 11:35:00|2024-12-22 13:07:00|   7632.35|      6000.0|          NULL|                       0|2024-12-26 13:34:00|      2024-12-26 12:00:00|2024-12-22 16:00:00|    2024-12-22 16:00:00| 1632.35| 1607.7|
# |   206432441|2024-12-22 11:35:00|2024-12-22 11:35:00|2024-12-22 13:07:00|   7632.35|      6000.0|          NULL|                       0|2024-12-26 13:34:00|      2024-12-26 12:00:00|2024-12-22 16:00:00|    2024-12-22 16:00:00| 1632.35| 1607.7|
# |   206432441|2024-12-22 11:35:00|2024-12-22 11:35:00|2024-12-22 13:07:00|   7632.35|      6000.0|          NULL|                       0|2024-12-26 13:34:00|      2024-12-26 12:00:00|2024-12-22 16:00:00|    2024-12-22 16:00:00| 1632.35| 1607.7|
# |   206432441|2024-12-22 11:35:00|2024-12-22 11:35:00|2024-12-22 13:07:00|   7632.35|      6000.0|          NULL|                       0|2024-12-26 13:34:00|      2024-12-26 12:00:00|2024-12-22 16:00:00|    2024-12-22 16:00:00| 1632.35| 1607.7|
# |   206432441|2024-12-22 11:35:00|2024-12-22 11:35:00|2024-12-22 13:07:00|   7632.35|      6000.0|          NULL|                       0|2024-12-26 13:34:00|      2024-12-26 12:00:00|2024-12-22 16:00:00|    2024-12-22 16:00:00| 1632.35| 1607.7|
# +------------+-------------------+-------------------+-------------------+----------+------------+--------------+------------------------+-------------------+-------------------------+-------------------+-----------------------+--------+-------+
# only showing top 20 rows

# %%
df_join = df_loadsmart.alias("loadsmart") \
            .join(
                df_book.alias("book"),
                col('loadsmart.loadsmart_id') == col('book.loadsmart_id'),
                how='inner'
            ) \
            .join(
                df_carriers.alias("carriers"),
                col('loadsmart.loadsmart_id') == col('carriers.loadsmart_id'),
                how='inner'
            ) \
            .join(
                df_delivery.alias("delivery"),
                col('loadsmart.loadsmart_id') == col('delivery.loadsmart_id'),
                how='inner'
            ) \
            .join(
                df_pickup.alias("pickup"),
                col('loadsmart.loadsmart_id') == col('pickup.loadsmart_id'),
                how='inner'
            ) \
            .join(
                df_shippers.alias("shippers"),
                col('loadsmart.loadsmart_id') == col('shippers.loadsmart_id'),
                how='inner'
            ) \
            .select(
                "loadsmart.loadsmart_id",
                "shippers.shipper_name",
                "delivery.delivery_date",
                "pickup.pickup_city",
                "pickup.pickup_state",
                "delivery.delivery_city",
                "delivery.delivery_state",
                "book.book_price",
                "carriers.carrier_name"
            )

# %%
df_join.select('delivery_date').distinct().sort(col('delivery_date').desc()).show()
# Out:
# [Stage 363:>                                                        (0 + 1) / 1]
# +-------------------+
# |      delivery_date|
# +-------------------+
# |2025-03-15 13:50:00|
# |2025-01-16 08:00:00|
# |2025-01-11 23:00:00|
# |2025-01-11 21:35:00|
# |2025-01-10 16:00:00|
# |2025-01-10 11:30:00|
# |2025-01-10 11:00:00|
# |2025-01-09 20:00:00|
# |2025-01-09 15:30:00|
# |2025-01-09 15:05:00|
# |2025-01-08 23:38:00|
# |2025-01-08 12:26:00|
# |2025-01-08 11:45:00|
# |2025-01-08 10:45:00|
# |2025-01-08 10:44:00|
# |2025-01-08 10:40:00|
# |2025-01-08 10:27:00|
# |2025-01-08 09:21:00|
# |2025-01-08 09:15:00|
# |2025-01-08 08:03:00|
# +-------------------+
# only showing top 20 rows

# %%
max_delivery_date = df_join.agg(max(col('delivery_date')).alias('max_delivery_date'))
get_last_month = max_delivery_date.select(to_timestamp(add_months(col('max_delivery_date'), -1)).alias('last_month_delivery')).first()[0]

max_delivery_date.show()

print(get_last_month)
print(type(get_last_month))
# Out:
# [Stage 379:>                                                        (0 + 1) / 1]
# +-------------------+
# |  max_delivery_date|
# +-------------------+
# |2025-03-15 13:50:00|
# +-------------------+
#
# 2025-02-15 00:00:00
# <class 'datetime.datetime'>

# %%
df_join = df_join.filter(col("delivery_date") == get_last_month)
df_join.show()
# Out:
# +------------+------------+-------------+-----------+------------+-------------+--------------+----------+------------+
# |loadsmart_id|shipper_name|delivery_date|pickup_city|pickup_state|delivery_city|delivery_state|book_price|carrier_name|
# +------------+------------+-------------+-----------+------------+-------------+--------------+----------+------------+
# +------------+------------+-------------+-----------+------------+-------------+--------------+----------+------------+

# %%
df_final = df_join.drop_duplicates()
df_final.show()
# Out:
# [Stage 387:>  (0 + 1) / 1][Stage 388:>  (0 + 1) / 1][Stage 389:>  (0 + 1) / 1]

# %%
df_final.count()
# Out:
# 5357

# %%
df_final.groupBy("loadsmart_id").agg(count('*').alias('total')).sort(col('total').desc()).show()
# Out:
# [Stage 149:>                                                        (0 + 1) / 1]
# +------------+-----+
# |loadsmart_id|total|
# +------------+-----+
# |   206429385|    1|
# |   206701857|    1|
# |   206628913|    1|
# |   206549705|    1|
# |   206690257|    1|
# |   206601449|    1|
# |   206535497|    1|
# |   206514105|    1|
# |   206550521|    1|
# |   206437929|    1|
# |   206438505|    1|
# |   206656609|    1|
# |   206569145|    1|
# |   206501081|    1|
# |   206628961|    1|
# |   206523817|    1|
# |   206647441|    1|
# |   206531585|    1|
# |   206608633|    1|
# |   206435417|    1|
# +------------+-----+
# only showing top 20 rows

# %%
df_final.write.csv("last_month_delivery.csv")
