# %%
# %pip install -r ./requirements.txt
# Out:
# Requirement already satisfied: ipykernel==7.1.0 in /home/leonardooliveira/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from -r ./requirements.txt (line 1)) (7.1.0)
# Requirement already satisfied: pyspark==3.5.7 in /home/leonardooliveira/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from -r ./requirements.txt (line 2)) (3.5.7)
# Requirement already satisfied: boto3==1.41.5 in /home/leonardooliveira/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from -r ./requirements.txt (line 3)) (1.41.5)
# Requirement already satisfied: comm>=0.1.1 in /home/leonardooliveira/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from ipykernel==7.1.0->-r ./requirements.txt (line 1)) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /home/leonardooliveira/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from ipykernel==7.1.0->-r ./requirements.txt (line 1)) (1.8.17)
# Requirement already satisfied: ipython>=7.23.1 in /home/leonardooliveira/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from ipykernel==7.1.0->-r ./requirements.txt (line 1)) (9.7.0)
# Requirement already satisfied: jupyter-client>=8.0.0 in /home/leonardooliveira/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from ipykernel==7.1.0->-r ./requirements.txt (line 1)) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/leonardooliveira/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from ipykernel==7.1.0->-r ./requirements.txt (line 1)) (5.9.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/leonardooliveira/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from ipykernel==7.1.0->-r ./requirements.txt (line 1)) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in /home/leonardooliveira/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from ipykernel==7.1.0->-r ./requirements.txt (line 1)) (1.6.0)
# Requirement already satisfied: packaging>=22 in /home/leonardooliveira/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from ipykernel==7.1.0->-r ./requirements.txt (line 1)) (25.0)
# Requirement already satisfied: psutil>=5.7 in /home/leonardooliveira/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from ipykernel==7.1.0->-r ./requirements.txt (line 1)) (7.1.3)
# Requirement already satisfied: pyzmq>=25 in /home/leonardooliveira/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from ipykernel==7.1.0->-r ./requirements.txt (line 1)) (27.1.0)
# Requirement already satisfied: tornado>=6.2 in /home/leonardooliveira/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from ipykernel==7.1.0->-r ./requirements.txt (line 1)) (6.5.2)
# Requirement already satisfied: traitlets>=5.4.0 in /home/leonardooliveira/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from ipykernel==7.1.0->-r ./requirements.txt (line 1)) (5.14.3)
# Requirement already satisfied: py4j==0.10.9.7 in /home/leonardooliveira/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from pyspark==3.5.7->-r ./requirements.txt (line 2)) (0.10.9.7)
# Requirement already satisfied: botocore<1.42.0,>=1.41.5 in /home/leonardooliveira/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from boto3==1.41.5->-r ./requirements.txt (line 3)) (1.41.5)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/leonardooliveira/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from boto3==1.41.5->-r ./requirements.txt (line 3)) (1.0.1)
# Requirement already satisfied: s3transfer<0.16.0,>=0.15.0 in /home/leonardooliveira/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from boto3==1.41.5->-r ./requirements.txt (line 3)) (0.15.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/leonardooliveira/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from botocore<1.42.0,>=1.41.5->boto3==1.41.5->-r ./requirements.txt (line 3)) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /home/leonardooliveira/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from botocore<1.42.0,>=1.41.5->boto3==1.41.5->-r ./requirements.txt (line 3)) (2.5.0)
# Requirement already satisfied: decorator>=4.3.2 in /home/leonardooliveira/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel==7.1.0->-r ./requirements.txt (line 1)) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /home/leonardooliveira/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel==7.1.0->-r ./requirements.txt (line 1)) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in /home/leonardooliveira/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel==7.1.0->-r ./requirements.txt (line 1)) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /home/leonardooliveira/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel==7.1.0->-r ./requirements.txt (line 1)) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/leonardooliveira/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel==7.1.0->-r ./requirements.txt (line 1)) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in /home/leonardooliveira/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel==7.1.0->-r ./requirements.txt (line 1)) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in /home/leonardooliveira/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel==7.1.0->-r ./requirements.txt (line 1)) (0.6.3)
# Requirement already satisfied: typing_extensions>=4.6 in /home/leonardooliveira/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel==7.1.0->-r ./requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: platformdirs>=2.5 in /home/leonardooliveira/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel==7.1.0->-r ./requirements.txt (line 1)) (4.5.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/leonardooliveira/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from jedi>=0.18.1->ipython>=7.23.1->ipykernel==7.1.0->-r ./requirements.txt (line 1)) (0.8.5)
# Requirement already satisfied: ptyprocess>=0.5 in /home/leonardooliveira/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel==7.1.0->-r ./requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: wcwidth in /home/leonardooliveira/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel==7.1.0->-r ./requirements.txt (line 1)) (0.2.14)
# Requirement already satisfied: six>=1.5 in /home/leonardooliveira/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.42.0,>=1.41.5->boto3==1.41.5->-r ./requirements.txt (line 3)) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in /home/leonardooliveira/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel==7.1.0->-r ./requirements.txt (line 1)) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/leonardooliveira/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel==7.1.0->-r ./requirements.txt (line 1)) (3.0.1)
# Requirement already satisfied: pure-eval in /home/leonardooliveira/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel==7.1.0->-r ./requirements.txt (line 1)) (0.2.3)
#
# [notice] A new release of pip is available: 23.2.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import split
import boto3

# %%
def create_spark_session():
        """
        Create and return a Spark session configured for AWS S3 access.
        Returns:
            SparkSession: Configured Spark session object.
        """
        aws_profile_name = "default"

        spark = SparkSession.builder \
                            .appName("SplitColumnExample") \
                            .config(
                                "spark.jars.packages",
                                "org.apache.hadoop:hadoop-aws:3.3.4,"
                                "com.amazonaws:aws-java-sdk-bundle:1.12.262"
                            ) \
                            .config(
                                "spark.hadoop.fs.s3a.aws.credentials.provider",
                                "com.amazonaws.auth.profile.ProfileCredentialsProvider"
                            ) \
                            .config("spark.hadoop.fs.s3a.profile", aws_profile_name) \
                            .getOrCreate()
        
        return spark

# %%
def get_s3_data():
    """
    Function to list and print S3 object keys in a specified bucket and prefix.
    Returns:
        str: S3 path of the last object found in the specified bucket and prefix.
    """

    s3 = boto3.client('s3')
    bucket_name = "data-challenge-loadsmart-stg"
    bucket_prefix = "data_challenge/"

    paginator = s3.get_paginator('list_objects_v2')
    page_iterator = paginator.paginate(Bucket=bucket_name, Prefix=bucket_prefix)

    for page in page_iterator:
        if 'Contents' in page:
            for obj in page['Contents']:
                print(obj['Key'])
                data_path = f"s3a://{bucket_name}/{obj['Key']}"

    return data_path

# %%
spark = create_spark_session()
data_path = get_s3_data()
# Out:
# :: loading settings :: url = jar:file:/home/leonardooliveira/.pyenv/versions/3.11.6/lib/python3.11/site-packages/pyspark/jars/ivy-2.5.1.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /home/leonardooliveira/.ivy2/cache
# The jars for the packages stored in: /home/leonardooliveira/.ivy2/jars
# org.apache.hadoop#hadoop-aws added as a dependency
# com.amazonaws#aws-java-sdk-bundle added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-bb28617b-bf72-49a9-a1cb-404f3d8990d1;1.0
# 	confs: [default]
# 	found org.apache.hadoop#hadoop-aws;3.3.4 in central
# 	found com.amazonaws#aws-java-sdk-bundle;1.12.262 in central
# 	found org.wildfly.openssl#wildfly-openssl;1.0.7.Final in central
# :: resolution report :: resolve 195ms :: artifacts dl 7ms
# 	:: modules in use:
# 	com.amazonaws#aws-java-sdk-bundle;1.12.262 from central in [default]
# 	org.apache.hadoop#hadoop-aws;3.3.4 from central in [default]
# 	org.wildfly.openssl#wildfly-openssl;1.0.7.Final from central in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |   3   |   0   |   0   |   0   ||   3   |   0   |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-bb28617b-bf72-49a9-a1cb-404f3d8990d1
# 	confs: [default]
# 	0 artifacts copied, 3 already retrieved (0kB/4ms)
# 25/11/30 07:33:25 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# data_challenge/_SUCCESS
# data_challenge/loading_date=2025-11-30/part-00000-b4cbcec7-c430-4556-a19f-7103b742e0da.c000.snappy.parquet

# %%
df = spark.read.parquet(data_path)
df.show()
# Out:
# 25/11/30 07:33:28 WARN MetricsConfig: Cannot locate configuration: tried hadoop-metrics2-s3a-file-system.properties,hadoop-metrics2.properties
# 25/11/30 07:33:33 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# +------------+--------------------+-------------------+-------------------+-------------------+-------------------+-------------------+----------+------------+--------+-------+--------------+--------------+----------------+-----------+------------------------+---------------+------------+-------------------------+---------------------------+-----------------------+-----------------------+-------------------------+-------------------------+-------------------------+-----------------------+----------------+---------------+------------------------+-------------------------+------------------+
00:00|                    false|                    false|                  false|           false|          false|                   false|                    false|             false|
# |   206437137|Fairfield,CA -> N...|2024-12-04 17:01:00|2024-12-04 17:01:00|2024-12-07 16:41:00|2024-12-07 15:00:00|2024-12-12 05:00:00|   7402.38|      7500.0|  -97.62| 2847.9|           RFR|          NULL|carrier_capacity|      false|                       1|Carrier 1695748|Shipper 1249|                    false|                       true|                  false|    2024-12-07 15:00:00|      2024-12-12 04:00:00|                    false|                    false|                  false|           false|          false|                   false|                    false|             false|
# |   206513177|Yakima,WA -> Uppe...|2024-12-28 19:43:00|2024-12-28 19:43:00|2025-01-02 16:38:00|2025-01-03 11:00:00|2025-01-08 08:03:00|   7371.42|      7500.0| -128.58| 2702.1|           RFR|          NULL|            NULL|      false|                       0|Carrier 1333902| Shipper 758|                     true|                       true|                   true|    2025-01-03 15:00:00|      2025-01-08 04:00:00|                    false|                    false|                  false|           false|          false|                   false|                    false|             false|
# |   206709073|Santa Ana,CA -> P...|2024-10-05 10:56:00|2024-10-05 10:56:00|2024-10-06 12:57:00|2024-10-09 15:00:00|2024-10-12 09:00:00|    7250.0|      7000.0|   250.0| 2509.6|           RFR|          NULL|            NULL|      false|                       0|Carrier 1695547| Shipper 585|                     true|                       true|                   true|    2024-10-09 15:00:00|      2024-10-12 08:00:00|                    false|                    false|                  false|           false|          false|                   false|                    false|             false|
# +------------+--------------------+-------------------+-------------------+-------------------+-------------------+-------------------+----------+------------+--------+-------+--------------+--------------+----------------+-----------+------------------------+---------------+------------+-------------------------+---------------------------+-----------------------+-----------------------+-------------------------+-------------------------+-------------------------+-----------------------+----------------+---------------+------------------------+-------------------------+------------------+
# only showing top 20 rows

# %%
df.count()
# Out:
# 5361

# %%
def split_column(df, select_columns, column_to_split, delimiter):
    """
    Split a column in a DataFrame into multiple columns based on a delimiter.
    Args:
        df (DataFrame): Input DataFrame.
        select_columns (list): List of columns to select from the DataFrame.
        column_to_split (str): Name of the column to split.
        delimiter (str): Delimiter used for splitting the column.
    Returns:
        DataFrame: DataFrame with the split columns.
    """

    split_df = df.select(*select_columns).withColumn("split_column",split(df[column_to_split], delimiter))

    split_df = split_df.withColumn("origin", split_df["split_column"].getItem(0)) \
                         .withColumn("destination", split_df["split_column"].getItem(1))
    
    split_df = split_df.withColumn("pickup_city", split(split_df["origin"], ",").getItem(0)) \
                         .withColumn("pickup_state", split(split_df["origin"], ",").getItem(1)) \
                         .withColumn("delivery_city", split(split_df["destination"], ",").getItem(0)) \
                         .withColumn("delivery_state", split(split_df["destination"], ",").getItem(1))
    return split_df

# %%
lanes = split_column(
    df,
    select_columns=["loadsmart_id", "lane"],
    column_to_split="lane",
    delimiter=" -> "
)

# %%
lanes.show(truncate=False)
# Out:
# [Stage 5:>                                                          (0 + 1) / 1]
# +------------+----------------------------------+----------------------------------+-------------+-----------------+-----------+------------+--------------+--------------+
# |loadsmart_id|lane                              |split_column                      |origin       |destination      |pickup_city|pickup_state|delivery_city |delivery_state|
# +------------+----------------------------------+----------------------------------+-------------+-----------------+-----------+------------+--------------+--------------+
# |206431033   |Hood River,OR -> Upper Marlboro,MD|[Hood River,OR, Upper Marlboro,MD]|Hood River,OR|Upper Marlboro,MD|Hood River |OR          |Upper Marlboro|MD            |
# |206521177   |Etowah,TN -> Reno,NV              |[Etowah,TN, Reno,NV]              |Etowah,TN    |Reno,NV          |Etowah     |TN          |Reno          |NV            |
# |206694049   |Salinas,CA -> Upper Marlboro,MD   |[Salinas,CA, Upper Marlboro,MD]   |Salinas,CA   |Upper Marlboro,MD|Salinas    |CA          |Upper Marlboro|MD            |
# |206553113   |Montpelier,OH -> Reno,NV          |[Montpelier,OH, Reno,NV]          |Montpelier,OH|Reno,NV          |Montpelier |OH          |Reno          |NV            |
# |206518817   |Newark,DE -> Portland,OR          |[Newark,DE, Portland,OR]          |Newark,DE    |Portland,OR      |Newark     |DE          |Portland      |OR            |
# |206427025   |Maxton,NC -> Portland,OR          |[Maxton,NC, Portland,OR]          |Maxton,NC    |Portland,OR      |Maxton     |NC          |Portland      |OR            |
# |206478177   |Maxton,NC -> Portland,OR          |[Maxton,NC, Portland,OR]          |Maxton,NC    |Portland,OR      |Maxton     |NC          |Portland      |OR            |
# |206754337   |Manning,SC -> Portland,OR         |[Manning,SC, Portland,OR]         |Manning,SC   |Portland,OR      |Manning    |SC          |Portland      |OR            |
# |206424601   |Montpelier,OH -> Reno,NV          |[Montpelier,OH, Reno,NV]          |Montpelier,OH|Reno,NV          |Montpelier |OH          |Reno          |NV            |
# |206554617   |Montpelier,OH -> Reno,NV          |[Montpelier,OH, Reno,NV]          |Montpelier,OH|Reno,NV          |Montpelier |OH          |Reno          |NV            |
# |206486537   |Santa Ana,CA -> Plant City,FL     |[Santa Ana,CA, Plant City,FL]     |Santa Ana,CA |Plant City,FL    |Santa Ana  |CA          |Plant City    |FL            |
# |206432441   |Trenton,MO -> Reno,NV             |[Trenton,MO, Reno,NV]             |Trenton,MO   |Reno,NV          |Trenton    |MO          |Reno          |NV            |
# |206490537   |Maxton,NC -> Portland,OR          |[Maxton,NC, Portland,OR]          |Maxton,NC    |Portland,OR      |Maxton     |NC          |Portland      |OR            |
# |206429353   |Santa Ana,CA -> Plant City,FL     |[Santa Ana,CA, Plant City,FL]     |Santa Ana,CA |Plant City,FL    |Santa Ana  |CA          |Plant City    |FL            |
# |206558993   |Salinas,CA -> Upper Marlboro,MD   |[Salinas,CA, Upper Marlboro,MD]   |Salinas,CA   |Upper Marlboro,MD|Salinas    |CA          |Upper Marlboro|MD            |
# |206426897   |Gonzales,CA -> Upper Marlboro,MD  |[Gonzales,CA, Upper Marlboro,MD]  |Gonzales,CA  |Upper Marlboro,MD|Gonzales   |CA          |Upper Marlboro|MD            |
# |206512777   |Lakewood,NY -> Portland,OR        |[Lakewood,NY, Portland,OR]        |Lakewood,NY  |Portland,OR      |Lakewood   |NY          |Portland      |OR            |
# |206437137   |Fairfield,CA -> Newark,NJ         |[Fairfield,CA, Newark,NJ]         |Fairfield,CA |Newark,NJ        |Fairfield  |CA          |Newark        |NJ            |
# |206513177   |Yakima,WA -> Upper Marlboro,MD    |[Yakima,WA, Upper Marlboro,MD]    |Yakima,WA    |Upper Marlboro,MD|Yakima     |WA          |Upper Marlboro|MD            |
# |206709073   |Santa Ana,CA -> Plant City,FL     |[Santa Ana,CA, Plant City,FL]     |Santa Ana,CA |Plant City,FL    |Santa Ana  |CA          |Plant City    |FL            |
# +------------+----------------------------------+----------------------------------+-------------+-----------------+-----------+------------+--------------+--------------+
# only showing top 20 rows

# %%
result = df.alias("origin") \
    .join(
        lanes.alias("lanes"),
        on="loadsmart_id",
        how="inner"
    ) \
    .select(
        "origin.*",
        "pickup_city",
        "pickup_state",
        "delivery_city",
        "delivery_state"
    )

result.show(truncate=False)
# Out:
# 25/11/30 07:33:43 WARN GarbageCollectionMetrics: To enable non-built-in garbage collector(s) List(G1 Concurrent GC), users should configure it(them) to spark.eventLog.gcMetrics.youngGenerationGarbageCollectors or spark.eventLog.gcMetrics.oldGenerationGarbageCollectors
# [Stage 7:>                                                          (0 + 1) / 1]
# +------------+----------------------------------+-------------------+-------------------+-------------------+-------------------+-------------------+----------+------------+--------+-------+--------------+--------------+----------------+-----------+------------------------+---------------+------------+-------------------------+---------------------------+-----------------------+-----------------------+-------------------------+-------------------------+-------------------------+-----------------------+----------------+---------------+------------------------+-------------------------+------------------+-----------+------------+--------------+--------------+
# |loadsmart_id|lane                              |quote_date         |book_date          |source_date        |pickup_date        |delivery_date      |book_price|source_price|pnl     |mileage|equipment_type|carrier_rating|sourcing_channel|vip_carrier|carrier_dropped_us_count|carrier_name   |shipper_name|carrier_on_time_to_pickup|carrier_on_time_to_delivery|carrier_on_time_overall|pickup_appointment_time|delivery_appointment_time|has_mobile_app_tracking23|has_mobile_app_tracking24|has_macropoint_tracking|has_edi_tracking|contracted_load|load_booked_autonomously|load_sourced_autonomously|load_was_cancelled|pickup_city|pickup_state|delivery_city |delivery_state|
# +------------+----------------------------------+-------------------+-------------------+-------------------+-------------------+-------------------+----------+------------+--------+-------+--------------+--------------+----------------+-----------+------------------------+---------------+------------+-------------------------+---------------------------+-----------------------+-----------------------+-------------------------+-------------------------+-------------------------+-----------------------+----------------+---------------+------------------------+-------------------------+------------------+-----------+------------+--------------+--------------+
# |206431033   |Hood River,OR -> Upper Marlboro,MD|2024-12-15 13:08:00|2024-12-15 13:09:00|2024-12-15 13:44:00|2024-12-15 11:00:00|2024-12-21 02:00:00|8922.51   |8500.0      |422.51  |2753.5 |RFR           |NULL          |dat_in          |false      |0                       |Carrier 605817 |Shipper 758 |true                     |true                       |true                   |2024-12-15 20:00:00    |2024-12-21 00:00:00      |false                    |false                    |false                  |false           |false          |false                   |false                    |false             |Hood River |OR          |Upper Marlboro|MD            |
# |206521177   |Etowah,TN -> Reno,NV              |2024-11-20 09:32:00|2024-11-20 09:32:00|2024-11-21 09:46:00|2024-11-21 14:00:00|2024-11-27 16:00:00|8726.17   |4000.0      |4726.17 |2331.3 |DRV           |NULL          |NULL            |false      |0                       |Carrier 1396487|Shipper 1644|true                     |true                       |true                   |2024-11-21 14:00:00    |2024-11-27 17:00:00      |false                    |false                    |false                  |false           |false          |false                   |false                    |false             |Etowah     |TN          |Reno          |NV            |
# |206694049   |Salinas,CA -> Upper Marlboro,MD   |2024-06-01 18:04:00|2024-06-01 18:04:00|2024-06-02 15:11:00|2024-06-03 02:00:00|2024-06-09 04:10:00|8548.19   |8220.0      |328.19  |3013.4 |RFR           |NULL          |NULL            |false      |0                       |Carrier 1044585|Shipper 758 |true                     |true                       |true                   |2024-06-03 02:00:00    |2024-06-08 23:00:00      |false                    |false                    |false                  |false           |false          |false                   |false                    |false             |Salinas    |CA          |Upper Marlboro|MD            |
# |206553113   |Montpelier,OH -> Reno,NV          |2024-11-20 09:10:00|2024-11-20 09:10:00|2024-11-20 12:39:00|2024-11-22 17:00:00|2024-11-28 19:00:00|8409.27   |5000.0      |3409.27 |2082.3 |DRV           |NULL          |NULL            |false      |0                       |Carrier 738    |Shipper 1644|true                     |true                       |true                   |2024-11-22 17:00:00    |2024-11-28 19:00:00      |false                    |false                    |false                  |false           |false          |false                   |false                    |false             |Montpelier |OH          |Reno          |NV            |
# |206518817   |Newark,DE -> Portland,OR          |2024-09-25 15:07:00|2024-09-25 15:07:00|2024-09-26 09:05:00|2024-09-26 17:00:00|2024-10-02 11:55:00|8351.95   |5500.0      |2851.95 |2847.7 |DRV           |NULL          |NULL            |false      |0                       |Carrier 14533  |Shipper 1644|true                     |true                       |true                   |2024-09-26 17:00:00    |2024-10-02 10:00:00      |false                    |false                    |false                  |false           |false          |false                   |false                    |false             |Newark     |DE          |Portland      |OR            |
# |206427025   |Maxton,NC -> Portland,OR          |2024-12-19 16:30:00|2024-12-19 16:30:00|2024-12-20 10:38:00|2024-12-23 15:00:00|2025-01-04 12:00:00|8140.88   |11050.0     |-2909.12|2863.1 |DRV           |NULL          |NULL            |false      |0                       |Carrier 1695246|Shipper 1644|true                     |true                       |true                   |2024-12-23 15:00:00    |2024-12-29 14:00:00      |false                    |false                    |false                  |false           |false          |false                   |false                    |false             |
00:00      |false                    |false                    |false                  |false           |false          |false                   |false                    |false             |Maxton     |NC          |Portland      |OR            |
# |206429353   |Santa Ana,CA -> Plant City,FL     |2024-10-05 10:52:00|2024-10-05 10:52:00|2024-10-06 11:27:00|2024-10-06 12:00:00|2024-10-09 12:30:00|7500.0    |7000.0      |500.0   |2509.6 |RFR           |NULL          |NULL            |false      |0                       |Carrier 1019564|Shipper 585 |false                    |true                       |true                   |2024-10-06 12:00:00    |2024-10-09 10:00:00      |false                    |false                    |false                  |false           |false          |false                   |false                    |false             |Santa Ana  |CA          |Plant City    |FL            |
# |206558993   |Salinas,CA -> Upper Marlboro,MD   |2024-05-18 18:48:00|2024-05-18 18:48:00|2024-05-19 13:30:00|2024-05-20 13:00:00|2024-05-25 23:55:00|7479.33   |7500.0      |-20.67  |3008.0 |RFR           |NULL          |NULL            |false      |0                       |Carrier 1027120|Shipper 758 |true                     |true                       |true                   |2024-05-20 13:00:00    |2024-05-25 23:00:00      |false                    |false                    |false                  |false           |false          |false                   |false                    |false             |Salinas    |CA          |Upper Marlboro|MD            |
# |206426897   |Gonzales,CA -> Upper Marlboro,MD  |2024-05-18 17:16:00|2024-05-18 17:16:00|2024-05-22 11:45:00|2024-05-22 11:00:00|2024-05-25 23:55:00|7475.63   |7500.0      |-24.37  |2948.9 |RFR           |NULL          |NULL            |false      |1                       |Carrier 1695273|Shipper 758 |true                     |true                       |true                   |2024-05-23 00:00:00    |2024-05-25 23:00:00      |false                    |false                    |false                  |false           |false          |false                   |false                    |false             |Gonzales   |CA          |Upper Marlboro|MD            |
# |206512777   |Lakewood,NY -> Portland,OR        |2024-11-05 19:46:00|2024-11-05 19:46:00|2024-11-06 12:37:00|2024-11-10 15:00:00|2024-11-17 17:00:00|7409.97   |5000.0      |2409.97 |2591.7 |DRV           |NULL          |NULL            |false      |0                       |Carrier 1058714|Shipper 1644|true                     |true                       |true                   |2024-11-10 15:00:00    |2024-11-14 18:00:00      |false                    |false                    |false                  |false           |false          |false                   |false                    |false             |Lakewood   |NY          |Portland      |OR            |
# |206437137   |Fairfield,CA -> Newark,NJ         |2024-12-04 17:01:00|2024-12-04 17:01:00|2024-12-07 16:41:00|2024-12-07 15:00:00|2024-12-12 05:00:00|7402.38   |7500.0      |-97.62  |2847.9 |RFR           |NULL          |carrier_capacity|false      |1                       |Carrier 1695748|Shipper 1249|false                    |true                       |false                  |2024-12-07 15:00:00    |2024-12-12 04:00:00      |false                    |false                    |false                  |false           |false          |false                   |false                    |false             |Fairfield  |CA          |Newark        |NJ            |
# |206513177   |Yakima,WA -> Upper Marlboro,MD    |2024-12-28 19:43:00|2024-12-28 19:43:00|2025-01-02 16:38:00|2025-01-03 11:00:00|2025-01-08 08:03:00|7371.42   |7500.0      |-128.58 |2702.1 |RFR           |NULL          |NULL            |false      |0                       |Carrier 1333902|Shipper 758 |true                     |true                       |true                   |2025-01-03 15:00:00    |2025-01-08 04:00:00      |false                    |false                    |false                  |false           |false          |false                   |false                    |false             |Yakima     |WA          |Upper Marlboro|MD            |
# +------------+----------------------------------+-------------------+-------------------+-------------------+-------------------+-------------------+----------+------------+--------+-------+--------------+--------------+----------------+-----------+------------------------+---------------+------------+-------------------------+---------------------------+-----------------------+-----------------------+-------------------------+-------------------------+-------------------------+-----------------------+----------------+---------------+------------------------+-------------------------+------------------+-----------+------------+--------------+--------------+
# only showing top 20 rows

# %%
result.count()
# Out:
# 5369
